# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/DataAnalysis/blob/main/2_2_1_%EB%84%90%EA%B0%92_%EC%B2%98%EB%A6%AC_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 다음 파일을 읽고 결측치 처리를 하시오 (https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv).

import pandas as pd

titanic = pd.read_csv('https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv', delimiter='\t')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 전체 컬럼이름 변경 ('passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sib', 'parch', 'ticket', 'fare', 'cabin', 'embarked')
titanic.columns = ['passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sib', 'parch', 'ticket', 'fare', 'cabin', 'embarked']
titanic.head()
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sib  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1
# 2                             Heikkinen, Miss. Laina  female  26.0    0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1
# 4                           Allen, Mr. William Henry    male  35.0    0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# age 컬럼에서 각 행의 널값 여부 (isna or isnull), 널값인 행 출력
print(titanic.age.isna())
print(titanic[titanic.age.isna()])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: age, Length: 156, dtype: bool
#      passengerId  survived  pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# ...

# %%
# age 컬럼에서 널값의 개수는?
print(titanic.age.isna().sum())
# Out:
# 30

# %%
# age컬럼이 널값인 사람의 age, name은?
print(titanic[titanic.age.isna()][['age', 'name']])
# Out:
#      age                                            name
# 5    NaN                                Moran, Mr. James
# 17   NaN                    Williams, Mr. Charles Eugene
# 19   NaN                         Masselmani, Mrs. Fatima
# 26   NaN                         Emir, Mr. Farred Chehab
# 28   NaN                   O'Dwyer, Miss. Ellen "Nellie"
# 29   NaN                             Todoroff, Mr. Lalio
# 31   NaN  Spencer, Mrs. William Augustus (Marie Eugenie)
# 32   NaN                        Glynn, Miss. Mary Agatha
# 36   NaN                                Mamee, Mr. Hanna
# 42   NaN                             Kraeff, Mr. Theodor
# 45   NaN                        Rogers, Mr. William John
# 46   NaN                               Lennon, Mr. Denis
# 47   NaN                       O'Driscoll, Miss. Bridget
# 48   NaN                             Samaan, Mr. Youssef
# 55   NaN                               Woolner, Mr. Hugh
# ...

# %%
# age 컬럼에서 각 행의 널값 여부 (notnull), 널값이 아닌 행 출력
print(titanic.age.notnull())
print(titanic[titanic.age.notnull()])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151     True
# 152     True
# 153     True
# 154    False
# 155     True
# Name: age, Length: 156, dtype: bool
#      passengerId  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 155          156         0       1
#
#                                                   name     sex   age  sib  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1
# 2                               Heikkinen, Miss. Laina  female  26.0    0
# ...

# %%
# age컬럼이 널값이 아닌 사람의 age, name은?
print(titanic[titanic.age.notnull()][['age', 'name']])
# Out:
#       age                                               name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 150  51.0                         Bateman, Rev. Robert James
# 151  22.0                  Pears, Mrs. Thomas (Edith Wearne)
# 152  55.5                                   Meo, Mr. Alfonzo
# 153  40.5                    van Billiard, Mr. Austin Blyler
# 155  51.0                        Williams, Mr. Charles Duane
#
# [126 rows x 2 columns]

# %%
# cabin컬럼의 널값을 N으로 채우기
titanic.cabin.fillna('N', inplace=True)
titanic.head()
# Out:
# <ipython-input-24-88dc2f4f10ab>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.cabin.fillna('N', inplace=True)
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sib  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1
# ...

# %%
# cabin컬럼의 첫번째 글자만 출력
titanic['cabin'].str[0]
# Out:
# 0      N
# 1      C
# 2      N
# 3      C
# 4      N
#       ..
# 151    C
# 152    N
# 153    N
# 154    N
# 155    N
# Name: cabin, Length: 156, dtype: object

# %%
# age컬럼의 널값을 age평균으로 채우기
titanic.age.fillna(titanic.age.mean(), inplace=True)
titanic.head()
# Out:
# <ipython-input-27-3753ab930f78>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.age.fillna(titanic.age.mean(), inplace=True)
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sib  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1
# ...
